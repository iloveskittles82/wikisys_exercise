# %% [markdown]
# <img src="https://th.bing.com/th/id/R.0b9618782d4e7062573f5983d876649a?rik=7HWDbD%2feXNOe1A&pid=ImgRaw&r=0" width=150>
#
#
# **I758 Wissens- und KI-basierte Systeme**
#
# # Explorative Datenanalyse: Verteilungen und Zusammenhänge
# (c) Ricardo Knauer, Raphael Wallsberger, Christina Kratsch

# %% [markdown]
# Willkommen bei der ersten praktischen Übung zum Thema explorative Datenanalyse! Wir haben uns während der Vorlesung bereits mit einigen Verfahren beschäftigt, mit denen man einen Datensatz erkunden kann. Im Folgenden wollen wir diese Verfahren auch praktisch anwenden. Zum Glück ist die explorative Analyse von Daten so weit verbreitet, dass es bereits eine Vielzahl an Bibliotheken für genau diesen Zweck gibt. Wir werden für unsere Analyse eine der bekanntesten Bibliotheken verwenden, um interaktive Diagramme zu erstellen: Plotly. Plotly verfügt über Schnittstellen zu einer ganzen Reihe an Programmiersprachen, darunter auch [Python](https://plotly.com/python/). Mit der ersten praktischen Übung verfolgen wir folgende Lernziele:
#
# - Sie sollen lernen, wie Sie Daten mithilfe von Säulen- oder Balkendiagrammen, Histogrammen, Streudiagrammen und Heatmaps in Plotly visualisieren können.
# - Sie sollen den Wert von Funktionsargumenten zur Visualisierung sach- und zweckorientiert anpassen können.
# - Sie sollen lernen, wie man eigene Hypothesen über einen Datensatz aufstellen und diese im Rahmen einer explorativen Analyse testen kann.
#
# Voraussichtlich werden Sie für diese Übung maximal 2h benötigen.

# %% [markdown]
# ## Der Datensatz

# %%
# Setup: installieren Sie die benötigten Bibliotheken

# conda activate wikisys
# conda install pandas matplotlib plotly scipy

# %% [markdown]
# Für die explorative Analyse von Daten braucht man als Ausgangspunkt erst einmal eins: Daten. Für unsere praktischen Übungen werden wir einen Datensatz verwenden, der uns freundlicherweise von [Prof. Dr. Stephan Matzka](https://www.htw-berlin.de/hochschule/personen/person/?eid=11248) zur Verfügung gestellt wurde. Der Datensatz befasst sich mit einer Fertigungszelle, in der drei Maschinen Produkte herstellen. Unser Datensatz ```machine_data.csv``` liegt im sogenannten csv-Format vor (englisch für _comma-separated values_). Das ist ein gängiges Format zum Speichern strukturierter Daten, bei dem einzelne Werte durch Kommas oder andere Trennzeichen separiert sind. Wenn wir uns die Datei anschauen, erkennen wir, dass die Trennzeichen in unserem Fall Semikolons sind und dass Floats ein Komma anstelle eines Punktes als Dezimaltrennzeichen aufweisen. Um den Datensatz einzulesen, nutzen wir die [pandas](https://pandas.pydata.org/)-Bibliothek - die erste Wahl bei der Arbeit mit tabellarischen Daten in Python. Eine kleine Anmerkung: Unter diesem Textabschnitt finden Sie einen Codeblock. Codeblöcke wie diesen können Sie ausführen, indem Sie auf den Block klicken und danach gleichzeitig SHIFT und ENTER auf der Tastatur drücken. Die entsprechende Ausgabe erscheint gegebenenfalls unter dem Block. Codeblöcke, die Sie zwischen den Texten in dieser Übung sehen, sollten Sie in der vorgegebenen Reihenfolge ausführen. Bei leeren Codeblöcken müssen Sie zuvor noch Ihren eigenen Code ergänzen.

# %%
import pandas as pd

df = pd.read_csv("data/machine_data.csv", delimiter=";", decimal=",")

# %% [markdown]
# Sie sehen, dass wir zuerst die pandas-Bibliothek importieren. Um bei Funktionsaufrufen aus dieser Bibliothek nicht jedes Mal ```pandas``` ausschreiben zu müssen, lassen wir Python wissen, dass wir das Kürzel ```pd``` anstelle von ```pandas``` benutzen möchten. Unseren csv-Datensatz können wir einlesen, indem wir einfach den Befehl ```pd.read_csv()``` ausführen. Dabei müssen wir der Funktion natürlich mitteilen, wo sich unsere Daten befinden und dass wir ```;``` als Trennzeichen sowie ```,``` als Dezimaltrennzeichen verwenden möchten. Der Datensatz wird abschließend in der Variable ```df``` in Form einer Tabelle gespeichert. Schauen wir uns die ersten paar Zeilen dieser Tabelle an. Dazu benutzen wir pandas' ```head()```-Funktion:

# %%
df.head(10)
# Out:
#   Maschine  Mode Produkt  Strom / A  Drehmoment / Nm  Drehzahl / 1/min  \
# 0        A   2.0       Y     22.782            51.79              1461
# 1        A   1.0       Y     19.793            45.03              1460
# 2        C   3.0       X     25.581            52.00              1463
# 3        C   3.0       Y     28.145            57.30              1461
# 4        C   2.0       Y     25.544            51.84              1466
# 5        A   2.0       X     21.426            48.64              1463
# 6        B   2.0       Y     22.786            50.92              1462
# 7        C   2.0       X     23.021            46.85              1462
# 8        B   2.0       Y     22.255            49.69              1463
# 9        C   3.0       X     26.195            53.29              1462
#
#    Temp Umgebung / degC  Temp Umrichter / degC  Temp Werkzeug / degC  \
# 0                  18.7                   23.1                  98.7
# 1                  21.0                   21.5                  87.5
# 2                  19.9                   21.8                  98.1
# 3                  20.7                   25.4                 109.7
# 4                  19.0                   24.1                 100.8
# 5                  21.5                   23.3                  95.1
# 6                  20.9                   22.8                  98.2
# 7                  21.3                   23.8                  93.1
# 8                  21.5                   24.4                  97.7
# 9                  21.9                   25.3                 104.1
#
#    Bearbeitungszeit / s
# 0                  23.8
# 1                  25.3
# 2                  19.9
# 3                  22.3
# 4                  23.8
# 5                  21.4
# 6                  24.8
# 7                  21.4
# 8                  24.8
# 9                  19.9

# %% [markdown]
# Die ersten drei Merkmale scheinen in Kategorien eingeteilt zu sein, bei den anderen Merkmalen handelt es sich anscheinend um Floats oder Integers. ```Maschine``` und ```Produkt``` sind offensichtlich nominale Merkmale; ```Mode``` ist hingegen ein ordinales Merkmal, da Energiesparbetrieb (```1.0```), Normalbetrieb (```2.0```) und Hochleistungsbetrieb (```3.0```) eine Rangordnung aufweisen. pandas verfügt natürlich nicht über diese Information aus der Dokumentation, daher müssen wir den ersten drei Merkmalen noch den passenden Datentyp zuweisen. Hierzu nutzen wir pandas' ```Categorical()```-Funktion:

# %%
df["Maschine"] = pd.Categorical(df["Maschine"])
df["Produkt"] = pd.Categorical(df["Produkt"])
df["Mode"] = pd.Categorical(df["Mode"], ordered=True)

# %% [markdown]
# Wie man in dem oberen Codeblock erkennen kann, kann man auf Spalten der Tabelle zugreifen, indem man den Namen der Spalte (als String) zwischen zwei eckige Klammern schreibt. Um pandas mitzuteilen, ob es sich bei einem Merkmal um ein nominales oder um ein ordinales Merkmal handelt, benutzt man in der ```Categorical()```-Funktion das Argument ```ordered```. Das Argument ist standardmäßig auf ```False``` gesetzt. Bei ordinalen Merkmalen muss man der Funktion daher explizit den Wert ```True``` mitgeben. Nachdem wir unseren Merkmalen in der Tabelle also nun die richtigen Datentypen zugewiesen haben, können wir uns endlich den Visualisierungen zuwenden.

# %% [markdown]
# <h5>Ein Merkmal, ein Diagramm, viele Kenngrößen</h5>

# %% [markdown]
# Sie haben in der Vorlesung bereits erfahren, dass es bei der explorativen Analyse zuerst meist sinnvoll ist, sich anzuschauen, wie oft die verschiedenen Werte in jedem Merkmal vorkommen. Bei nominalen und ordinalen Merkmalen bieten sich Säulen- oder Balkendiagramme zur Visualisierung an, bei metrischen Merkmalen Histogramme. Um interaktive Diagramme zu erstellen, können wir pandas ganz einfach mit Plotly kombinieren. Dazu setzen wir das sogenannte Backend zur Darstellung von Diagrammen auf ```"plotly"```:

# %%
pd.options.plotting.backend = "plotly"

# %% [markdown]
# Ein [Säulendiagramm](https://plotly.github.io/plotly.py-docs/generated/plotly.express.bar.html) können wir darstellen, indem wir die Anzahl der Werte pro Kategorie mit der ```value_counts()```-Funktion zählen und danach ```plot(kind="bar")``` aufrufen. Für das nominale Merkmal ```Maschine``` sähe das wie folgt aus:

# %%
df["Maschine"].value_counts().plot(kind="bar")

# %% [markdown]
# Das entsprechende [Balkendiagramm](https://plotly.github.io/plotly.py-docs/generated/plotly.express.bar.html) sähe so aus:

# %%
df["Maschine"].value_counts().plot(kind="bar", orientation="h")

# %% [markdown]
# <span style="color:#FF5F00"><b>AUFGABE 1:</b></span><br>
# Stellen Sie selbstständig ein Säulen- oder Balkendiagramm für das nominale Merkmal ```Produkt``` dar. Was fällt Ihnen auf?

# %%
df["Produkt"].value_counts().plot(kind="bar")

# %% [markdown]
# <span style="color:green"><b>Geben Sie nachfolgend Ihre schriftliche Antwort zur AUFGABE 1:</b></span><br>

# %% [markdown]
# Am häufigsten wird Produkt "Y" bearbeitet (541 mal), dicht gefolgt von "X" (458 mal).
#
# Auffällig ist, dass nur ein einziges mal das Produkt "Z" bearbeitet wurde.
#
# ---

# %% [markdown]
# Widmen wir uns als nächstes den metrischen Merkmalen. Metrische Merkmale kann man in Wertebereiche (englisch _bins_) einteilen und in einem [Histogramm](https://plotly.github.io/plotly.py-docs/generated/plotly.express.histogram.html) visualisieren. Ein Histogramm stellt eine Häufigkeitsverteilung dar, die man mit einigen Eigenschaften charakterisieren kann. Eventuell möchten Sie auf Wikipedia kurz nachschauen, was ein Mittelwert, eine Standardabweichung, ein Median sowie Quantile sind.

# %% [markdown]
# Ein Histogramm lässt sich mit Plotly ganz einfach darstellen, zum Beispiel für die Drehzahl pro Minute:

# %%
df["Drehzahl / 1/min"].plot(kind="histogram")

# %% [markdown]
# <span style="color:#FF5F00"><b>AUFGABE 2:</b></span><br>
# Versuchen Sie, mit der Histogramm-Funktion zu spielen: stellen Sie selbständig ein Histogramm von der Stromaufnahme in Ampere dar. Was fällt Ihnen an dieser Verteilung auf?

# %%
df["Strom / A"].plot(kind="histogram", nbins=100)

# %% [markdown]
# <span style="color:green"><b>Geben Sie nachfolgend Ihre schriftliche Antwort zur AUFGABE 2:</b></span><br>

# %% [markdown]
# Das Diagramm zeigt die Verteilung der Stromnutzung bei einzelnen Fertigungsschritten. Es sind 5 glockenförmige Häufungen zu erkennen (ähnlich zu Normalverteilungen), wobei die linkesten beiden (ca. bei 20 & 21) sehr nah und fast überlappend liegen und die außerste (bei 28) nur sehr klein ist.
#
# Die Häufungen liegen bei:
#
# 1. 20
# 2. 21
# 3. 23
# 4. 26
# 5. 28
#
# Die Unterschiede kommen vermutlich durch die verschiedenen Maschinen und deren Operating-Modes zustande.
#
# ---

# %% [markdown]
# Vielleicht ist Ihnen aufgefallen, dass sich die Anzahl der Wertebereiche zwischen den beiden Histogrammen unterscheidet. Im Histogramm zur Drehzahl pro Minute gibt es 12 solcher Bereiche, im Histogramm zur Stromaufname in Ampere 24. In Plotly gibt es einen Algorithmus, der die optimale Anzahl und Breite der Wertebereiche automatisch festlegt. Man kann allerdings über das ```nbins```-Argument zumindest die maximale Anzahl der Wertebereiche bestimmen.
#
# <span style="color:#FF5F00"><b>AUFGABE 3:</b></span><br>
# Setzen Sie das ```nbins```-Argument auf ```100``` und beobachten Sie, wie sich das Histogramm verändert. Fällt Ihnen bei der Häufigkeitsverteilung etwas auf, das Ihnen bei einer kleineren Anzahl von Wertebereichen vielleicht nicht aufgefallen wäre (Stichwort: Ausreißer)? Lohnt sich das Testen einer größeren Anzahl von Wertebereichen oder genügt die Standardeinstellung?

# %%
df["Strom / A"].plot(kind="histogram", nbins=100)

# %% [markdown]
# <span style="color:green"><b>Geben Sie nachfolgend Ihre schriftliche Antwort zur AUFGABE 3:</b></span><br>

# %% [markdown]
# Durch die erhöhte Auflösung lassen sich auch sehr eng gruppierte Häufungen, also welche, bei denen die Werte sehr dicht beieinander liegen, erkennen. So wird beispielsweise auch die Grenze zwischen den ersten beiden Häufungen sowie die letzte Häufung klarer erkennbar.
#
# Nachteil ist allerdings, dass eine zu hohe Anzahl an *bins* das Erkennen von Häufungen schwerer macht, da mehr Lücken in den Werten sichtbar werden. Bei geringerer Anzahl werden diese Lücken einfacher *"aufgesaugt"*.
#
# ---

# %% [markdown]
# <span style="color:#FF5F00"><b>AUFGABE 4:</b></span><br>
# Zuletzt wollen wir uns noch anschauen, wie wir relative anstatt absolute Häufigkeiten angeben können. Nutzen Sie hierfür das ```histnorm```-Argument und setzen es auf ```"probability"```:

# %%
df["Strom / A"].plot(kind="histogram", nbins=100, histnorm="probability")

# %% [markdown]
# Natürlich ergibt es noch Sinn, die anderen Merkmale zu visualisieren. Da Ihnen die Funktionsaufrufe hierfür aber nun bekannt sein sollten, möchten wir an dieser Stelle darauf verzichten. Stattdessen wollen wir unsere Häufigkeitsverteilungen in einigen Kenngrößen zusammenzufassen. Dafür nutzen wir pandas' ```describe()```-Funktion und setzen ```include``` auf ```"all"```:

# %%
df.describe(include="all")
# Out:
#        Maschine   Mode Produkt   Strom / A  Drehmoment / Nm  Drehzahl / 1/min  \
# count      1000  999.0    1000  999.000000      1000.000000       1000.000000
# unique        3    3.0       3         NaN              NaN               NaN
# top           C    2.0       Y         NaN              NaN               NaN
# freq        416  518.0     541         NaN              NaN               NaN
# mean        NaN    NaN     NaN   22.501915        48.555380       1460.945000
# std         NaN    NaN     NaN    2.520593         3.692908          1.916154
# min         NaN    NaN     NaN   18.221000        41.430000       1456.000000
# 25%         NaN    NaN     NaN   20.435500        45.527500       1460.000000
# 50%         NaN    NaN     NaN   22.102000        47.515000       1461.000000
# 75%         NaN    NaN     NaN   24.668000        51.602500       1462.000000
# max         NaN    NaN     NaN   29.530000        60.110000       1467.000000
#
#         Temp Umgebung / degC  Temp Umrichter / degC  Temp Werkzeug / degC  \
# count            1000.000000            1000.000000           1000.000000
# unique                   NaN                    NaN                   NaN
# top                      NaN                    NaN                   NaN
# freq                     NaN                    NaN                   NaN
# mean               20.984700              23.750500             95.196400
# std                 1.374695               1.040876              5.688506
# min                17.300000              20.300000             82.900000
# 25%                20.100000              23.075000             90.600000
# 50%                21.000000              23.700000             94.000000
# 75%                21.900000              24.400000             99.800000
# max                26.000000              27.400000            113.100000
#
#         Bearbeitungszeit / s
# count            1000.000000
# unique                   NaN
# top                      NaN
# freq                     NaN
# mean               23.008900
# std                 1.970897
# min                19.900000
# 25%                21.400000
# 50%                22.400000
# 75%                25.300000
# max                25.300000

# %% [markdown]
# Durch diesen Funktionsaufruf werden eine ganze Menge Kenngrößen ausgegeben. Unter ```count``` wird die Anzahl von nicht-fehlenden Werten angegeben (also von Werten, die nicht "not a number" bzw. ```NaN``` sind), unter ```unique``` wird die Anzahl der Kategorien bei nominalen und ordinalen Daten angegeben, unter ```top``` der Modus und unter ```freq``` die Häufigkeit des Modus. Während uns ```count``` einen Aufschluss über die Datenqualität gibt, liefern uns ```unique```, ```top``` und ```freq``` eigentlich keine zusätzliche Information im Vergleich zu unserer interaktiven Visualisierung. Interessanter ist die Angabe des arithmetischen Mittels ```mean```, der Standardabweichung ```std```, des Minimums ```min```, des unteren Quartils ```25%```, des mittleres Quartils bzw. Medians ```50%```, des oberen Quartils ```75%``` sowie des Maximums ```max```. Weitere Streuungsmaße wie die Varianz, die Spannweite oder der Interquartilsabstand können bei Bedarf aus diesen Kenngrößen einfach berechnet werden. Sie erinnern sich, dass jedes dieser Lage- und Streuungsmaße bestimmte Vor- und Nachteile aufweist. Eine allgemeine Empfehlung, welches Maß zu bevorzugen ist, kann man daher nicht abgeben.

# %% [markdown]
# <span style="color:#FF5F00"><b>AUFGABE 5:</b></span><br>
# Wählen Sie nun ein metrisches Merkmal aus, bei dem es einen Unterschied ≥ 1 zwischen dem arithmetischen Mittel und dem Median gibt. Überlegen Sie sich, was Gründe für den Unterschied sein könnten. Überprüfen Sie Ihre Vermutungen dann durch eine passende Visualisierung!

# %% [markdown]
# <span style="color:green"><b>Geben Sie nachfolgend Ihre schriftliche Antwort zur Aufgabe 5:</b></span><br>

# %% [markdown]
# Ich vermute, dass der Unterschied zwischen **arithmetischem Mittel (ca. `48.56 Nm`)** und **Median (ca. `47.52 Nm`)** daher kommt, dass es einige wenige "Ausreißer" mit besonders hohen Drehmoments-Werten in den Daten gibt, die den Durchschnitt stark beeinflussen.
#
# Im untenstehenden Diagramm sieht man eindeutig zwei Häufungen an Werten, die rechts und links des Medians und Durchschnitts liegen. Diese Häufungen scheinen *Normalverteilungen* um ca. `46 Nm` (links) und `52 Nm` (rechts) abzubilden.
# Eine dritte, in der Anzahl (also Höhe der Balken) deutlich kleinere Häufung befindet sich um ca. `57.5 Nm`.
#
# Diese ist vermutlich für den Unterschied zwischen Median und arithmetischem Mittel verantwortlich, da Werte, die eine große Abweichung vom Durchschnitt aufweisen, diesen stärker beeinflussen, als Werte, die nur eine geringe Abweichung aufweisen.

# %%
df["Drehmoment / Nm"].plot(kind="histogram")

# %% [markdown]
# ---

# %% [markdown]
# ## Korrelationen untersuchen

# %% [markdown]
# Wir hoffen, dass wir Sie bereits von den Fähigkeiten von pandas und Plotly für die explorative Datenanalyse überzeugen konnten. Sie haben gesehen, dass es für die Darstellung eines Säulen- oder Balkendiagramms oder eines Histogramms jeweils nur einer einzigen Zeile Code bedarf; auch Lage- und Streuungsmaße können mit nur einer einzigen Zeile Code ausgegeben werden (bzw. drei Zeilen Code, wenn man auch unsere Implementierung für ordinale Merkmale verwenden möchte). Richtig interessant wird es oft aber erst, wenn wir nach weiteren Mustern und Zusammenhängen in den Daten suchen. Dazu müssen wir uns mehr als nur ein Merkmal zur gleichen Zeit anschauen. Wir gehen im Folgenden davon aus, dass wir nach unserer explorativen Analyse noch eine gezielte Analyse zu interessanten Muster und Zusammenhängen planen. Um Aussagen über unsere Stichprobe hinaus treffen zu können, müssen wir unsere Erkenntnisse später auf einem unabhängigen Datensatz testen können und daher an dieser Stelle unsere Daten in einen Explorations- und einen Testdatensatz aufteilen. Wir nutzen dazu eine einfache Randomisierung. Wir wählen also mit der ```sample()```-Funktion einen bestimmten Bruchteil unserer Daten zufällig zum Explorieren aus, zum Beispiel 75% bzw. ```0.75```. Um eine reproduzierbare Aufteilung zu erhalten, fixieren wir zudem den [Startwert des Zufallszahlengenerators](https://de.wikipedia.org/wiki/Seed_key), zum Beispiel auf ```42```:

# %%
import pandas as pd

df = pd.read_csv("data/machine_data.csv", delimiter=";", decimal=",")
df["Maschine"] = pd.Categorical(df["Maschine"])
df["Produkt"] = pd.Categorical(df["Produkt"])
df["Mode"] = pd.Categorical(df["Mode"], ordered=True)

exploration_data = df.sample(frac=0.75, random_state=42)
exploration_data
# Out:
#     Maschine Mode Produkt  Strom / A  Drehmoment / Nm  Drehzahl / 1/min  \
# 521        A  1.0       Y     19.328            43.92              1461
# 737        C  1.0       Y     21.265            43.37              1459
# 740        A  1.0       Y     20.198            45.96              1459
# 660        C  3.0       X     25.700            52.28              1462
# 411        C  1.0       Y     21.949            44.61              1464
# ..       ...  ...     ...        ...              ...               ...
# 641        A  2.0       Y     22.299            50.61              1463
# 915        C  2.0       X     22.801            46.49              1459
# 752        C  3.0       X     26.118            53.16              1462
# 806        A  1.0       Y     20.283            46.11              1461
# 919        B  2.0       X     20.514            45.86              1461
#
#      Temp Umgebung / degC  Temp Umrichter / degC  Temp Werkzeug / degC  \
# 521                  22.6                   23.5                  88.6
# 737                  19.8                   23.0                  86.7
# 740                  19.2                   23.2                  90.9
# 660                  22.8                   25.5                 102.4
# 411                  18.9                   22.5                  87.9
# ..                    ...                    ...                   ...
# 641                  19.8                   22.6                  97.6
# 915                  20.6                   23.2                  91.9
# 752                  20.4                   22.7                 101.1
# 806                  19.3                   23.3                  91.0
# 919                  21.5                   24.2                  91.9
#
#      Bearbeitungszeit / s
# 521                  25.3
# 737                  25.3
# 740                  25.3
# 660                  19.9
# 411                  25.3
# ..                    ...
# 641                  23.8
# 915                  21.4
# 752                  19.9
# 806                  25.3
# 919                  22.4
#
# [750 rows x 10 columns]

# %% [markdown]
# ### Zusammenhang von Merkmalen
#
# Nachdem wir nun einen Explorationsdatensatz erstellt haben, können wir uns den Zusammenhang von Merkmalen für diesen Datensatz anschauen. Hierzu erstellen wir ein [Streudiagramm](https://plotly.github.io/plotly.py-docs/generated/plotly.express.scatter.html), zum Beispiel für die Stromaufnahme in Ampere und das Drehmoment in Newtonmeter:

# %%
exploration_data.plot(kind="scatter", x="Strom / A", y="Drehmoment / Nm")

# %% [markdown]
# Für die Maschinen müssen wir den Code etwas umständlicher formulieren, da sich die Plot-Funktion mit kategorischen Variablen etwas schwer tun kann...

# %%
import matplotlib.pyplot as plt
groups = exploration_data.groupby('Maschine')

fig, ax = plt.subplots()
for name, group in groups:
    ax.plot(group['Strom / A'], group['Drehmoment / Nm'], marker='o', linestyle='', ms=12, label=name)
_ = ax.legend()

# %% [markdown]
# <span style="color:#FF5F00"><b>AUFGABE 6:</b></span><br>Die beiden Streudiagramme zeigen, dass sich die drei geraden Linien durch die verschiedenen Maschinen ergeben. Testen Sie als nächstes den Zusammenhang zwischen der Stromaufnahme in Ampere und der Werkzeug-Temperatur in °Celsius. Was können Sie erkennen?

# %%
fig, ax = plt.subplots()
for name, group in groups:
    ax.plot(group['Strom / A'], group['Temp Werkzeug / degC'], marker='o', linestyle='', ms=12, label=name)
_ = ax.legend()

# %% [markdown]
# <span style="color:green"><b>Geben Sie nachfolgend Ihre schriftliche Antwort zur AUFGABE 6:</b></span><br>
#
# Wie bereits in dem vorigen Diagramm zeigt sich hier eine klare lineare Abhängigkeit zwischen den verglichenen Messwerten für jede der drei Maschinen. Unterschiedlich sind hier allerdings die Abweichungen der Punkte vom "idealen" linearen Verlauf. Diese Abweichungen sind hier viel größer als im obigen, wo sie nahezu perfekte Linien bilden.
#
# Es gibt also deutlich mehr Streuung, doch ist die Abhängigkeit vom genutzten Strom und der Temperatur des Werkzeugs deutlich zu sehen.
#
# Wenn Werkzeugtemperatur vom Strom und das Drehmoment ebenfalls vom Strom abhängig ist, dann sollte sich auch eine interessante Abhängigkeit zwischen Temperatur und Drehmoment zeigen:

# %%
fig, ax = plt.subplots()
for name, group in groups:
    ax.plot(group['Temp Werkzeug / degC'], group['Drehmoment / Nm'], marker='o', linestyle='', ms=12, label=name)
_ = ax.legend()

# %% [markdown]
# Auch hier zeigt sich deutlich die lineare Abhängigkeit, allerdings liegen die Werte der drei Maschinen nun übereinander.
#
# ---

# %% [markdown]
# <span style="color:#FF5F00"><b>AUFGABE 6.1:</b></span><br>Um Ihnen eine bessere Intuition über die Größe und Richtung eines Zusammenhangs zu geben, haben wir eine Auswahl an Streudiagrammen mit unterschiedlichen Zusammenhängen zusammengestellt. Versuchen Sie, die unten aufgeführten Zusammenhänge einzuschätzen. Ist der folgende Zusammenhang groß oder klein, positiv oder negativ?
#
# <img src="./img/corr_10.svg" height=200>

# %% [markdown]
# <span style="color:green"><b>Geben Sie nachfolgend Ihre schriftliche Antwort zur AUFGABE 6.1:</b></span><br>

# %% [markdown]
# Die Linie zeigt einen starken positiven linearen Zusammenhang zwischen der X- und Y-Achse, mit einem Faktor gegen `1`.

# %% [markdown]
# ---

# %% [markdown]
# <span style="color:#FF5F00"><b>AUFGABE 6.2:</b></span><br>Wie sieht es bei dem nächsten Zusammenhang aus?
#
# <img src="./img/corr_-10.svg" height=200>

# %% [markdown]
# <span style="color:green"><b>Geben Sie nachfolgend Ihre schriftliche Antwort zur AUFGABE 6.2:</b></span><br>

# %% [markdown]
# Diese Linie zeigt einen starken negativen linearen Zusammenhang mit einem Faktor gegen `-1`.
#
# ---

# %% [markdown]
# <span style="color:#FF5F00"><b>AUFGABE 6.3:</b></span><br>Überlegen Sie, wie ein Streudiagramm aussehen würde, wenn es keinen Zusammenhang zwischen den Merkmalen gäbe. Beschreiben Sie dann den folgenden Zusammenhang:
#
# <img src="./img/corr_00.svg" height=200>

# %% [markdown]
# <span style="color:green"><b>Geben Sie nachfolgend Ihre schriftliche Antwort zur AUFGABE 6.3:</b></span><br>

# %% [markdown]
# Ein Diagramm ohne Zusammenhang der Achsen wäre ein völlig wirrer, ungeordneter Haufen Punkte. Hier zeigt sich jedoch etwas, das einer Parabel ähnelt. Dieser etwas schwache, aber definitiv bestehende Zusammenhang ist durch recht große Streuung eher als ein Band anstatt einer Linie zu erkennen.
#
# ---

# %% [markdown]
# <span style="color:#FF5F00"><b>AUFGABE 6.4:</b></span><br>Schätzen Sie zum Schluss noch diesen Zusammenhang ein:
#
# <img src="./img/corr_08.svg" height=200>

# %% [markdown]
# <span style="color:green"><b>Geben Sie nachfolgend Ihre schriftliche Antwort zur AUFGABE 6.4:</b></span><br>

# %% [markdown]
# Hier zeigt sich ein ähnlicher Zusammenhang wie in **[AUFGABE 6.1]**, allerdings mit deutlich mehr Streuung. Das heißt, dass dieser Zusammenhang etwas schwächer ist als der erste.
#
# Würde man Trendlinien für beide Diagramme einzeichnen, lägen diese vermutlich sehr nah aneinander.
#
# ---

# %% [markdown]
# Möchten Sie Ihre Intuition über die Größe von Zusammenhängen (mit dem Korrelationskoeffizienten nach Pearson) noch weiter ausbauen, empfehlen wir Ihnen das Online-Spiel [Guess the Correlation](http://guessthecorrelation.com/).

# %% [markdown]
# ## Korrelationen und Transformationen

# %% [markdown]
# Mit dem besseren Verständnis über die Stärke und Richtung von Zusammenhängen können wir uns nun direkt die Korrelationskoeffizienten nach Pearson für unsere metrischen Merkmale anschauen. Dazu benutzen wir die ```corr()```-Funktion (zur Bestimmung der Korrelationen) in Verbindung mit ```"plt.imshow"``` (kurz für _image show_) und passenden Farben (```"RdBu_r"```) zur Erstellung einer [Heatmap](https://plotly.github.io/plotly.py-docs/generated/plotly.express.imshow.html). Versuchen Sie, sich anhand der Farben und Ihrem Wissen über den Pearsons Correlation einen Reim aus der Matrix zu machen:

# %%
corr = exploration_data.corr(numeric_only=True)
plt.imshow(corr, cmap="RdBu")
plt.xticks(range(len(corr)), corr.columns, rotation=90)
_ = plt.yticks(range(len(corr)), corr.index)

# %% [markdown]
# Die Matrix ist etwas schwer zu lesen und es ist mühsam, die Label ordentlich an die Achsen zu schreiben. Dankenswerterweise gibt es unzählige Möglichkeiten, mit ```pandas``` und den zugehörigen Visualisierungsbibliotheken wie z.B. ```plotly```, ```matplotlib``` und ```seaborn``` ansprechende Visualisierungen zu gestalten. Die Kunst liegt vor allem darin, die Bibliotheken auseinander zu halten und die richtige auszuwählen, z.B. um eine geclusterte Heatmap zu erzeugen:

# %%
corr.style.background_gradient(vmin=-1, vmax=1, cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_625cb_row0_col0, #T_625cb_row1_col1, #T_625cb_row2_col2, #T_625cb_row3_col3, #T_625cb_row4_col4, #T_625cb_row5_col5, #T_625cb_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_625cb_row0_col1, #T_625cb_row1_col0 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_625cb_row0_col2, #T_625cb_row1_col2, #T_625cb_row2_col0, #T_625cb_row2_col1 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_625cb_row0_col3, #T_625cb_row3_col0 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_625cb_row0_col4, #T_625cb_row4_col0 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_625cb_row0_col5, #T_625cb_row5_col0 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_625cb_row0_col6, #T_625cb_row6_col0 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_625cb_row1_col3, #T_625cb_row3_col1 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_625cb_row1_col4, #T_625cb_row4_col1 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_625cb_row1_col5, #T_625cb_row5_col1 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_625cb_row1_col6, #T_625cb_row5_col6, #T_625cb_row6_col1, #T_625cb_row6_col5 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_625cb_row2_col3, #T_625cb_row2_col4, #T_625cb_row3_col2, #T_625cb_row4_col2 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_625cb_row2_col5, #T_625cb_row5_col2 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_625cb_row2_col6, #T_625cb_row6_col2 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_625cb_row3_col4, #T_625cb_row4_col3 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_625cb_row3_col5, #T_625cb_row5_col3 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_625cb_row3_col6, #T_625cb_row6_col3 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_625cb_row4_col5, #T_625cb_row5_col4 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_625cb_row4_col6, #T_625cb_row6_col4 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# </style>
# <table id="T_625cb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_625cb_level0_col0" class="col_heading level0 col0" >Strom / A</th>
#       <th id="T_625cb_level0_col1" class="col_heading level0 col1" >Drehmoment / Nm</th>
#       <th id="T_625cb_level0_col2" class="col_heading level0 col2" >Drehzahl / 1/min</th>
#       <th id="T_625cb_level0_col3" class="col_heading level0 col3" >Temp Umgebung / degC</th>
#       <th id="T_625cb_level0_col4" class="col_heading level0 col4" >Temp Umrichter / degC</th>
#       <th id="T_625cb_level0_col5" class="col_heading level0 col5" >Temp Werkzeug / degC</th>
#       <th id="T_625cb_level0_col6" class="col_heading level0 col6" >Bearbeitungszeit / s</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_625cb_level0_row0" class="row_heading level0 row0" >Strom / A</th>
#       <td id="T_625cb_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_625cb_row0_col1" class="data row0 col1" >0.908122</td>
#       <td id="T_625cb_row0_col2" class="data row0 col2" >-0.000045</td>
#       <td id="T_625cb_row0_col3" class="data row0 col3" >-0.049613</td>
#       <td id="T_625cb_row0_col4" class="data row0 col4" >0.209184</td>
#       <td id="T_625cb_row0_col5" class="data row0 col5" >0.898679</td>
#       <td id="T_625cb_row0_col6" class="data row0 col6" >-0.573392</td>
#     </tr>
#     <tr>
#       <th id="T_625cb_level0_row1" class="row_heading level0 row1" >Drehmoment / Nm</th>
#       <td id="T_625cb_row1_col0" class="data row1 col0" >0.908122</td>
#       <td id="T_625cb_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_625cb_row1_col2" class="data row1 col2" >-0.006215</td>
#       <td id="T_625cb_row1_col3" class="data row1 col3" >-0.034505</td>
#       <td id="T_625cb_row1_col4" class="data row1 col4" >0.194446</td>
#       <td id="T_625cb_row1_col5" class="data row1 col5" >0.981825</td>
#       <td id="T_625cb_row1_col6" class="data row1 col6" >-0.492981</td>
#     </tr>
#     <tr>
#       <th id="T_625cb_level0_row2" class="row_heading level0 row2" >Drehzahl / 1/min</th>
#       <td id="T_625cb_row2_col0" class="data row2 col0" >-0.000045</td>
#       <td id="T_625cb_row2_col1" class="data row2 col1" >-0.006215</td>
#       <td id="T_625cb_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_625cb_row2_col3" class="data row2 col3" >0.035159</td>
#       <td id="T_625cb_row2_col4" class="data row2 col4" >0.034131</td>
#       <td id="T_625cb_row2_col5" class="data row2 col5" >0.014837</td>
#       <td id="T_625cb_row2_col6" class="data row2 col6" >-0.007918</td>
#     </tr>
#     <tr>
#       <th id="T_625cb_level0_row3" class="row_heading level0 row3" >Temp Umgebung / degC</th>
#       <td id="T_625cb_row3_col0" class="data row3 col0" >-0.049613</td>
#       <td id="T_625cb_row3_col1" class="data row3 col1" >-0.034505</td>
#       <td id="T_625cb_row3_col2" class="data row3 col2" >0.035159</td>
#       <td id="T_625cb_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_625cb_row3_col4" class="data row3 col4" >0.585495</td>
#       <td id="T_625cb_row3_col5" class="data row3 col5" >0.077946</td>
#       <td id="T_625cb_row3_col6" class="data row3 col6" >0.024696</td>
#     </tr>
#     <tr>
#       <th id="T_625cb_level0_row4" class="row_heading level0 row4" >Temp Umrichter / degC</th>
#       <td id="T_625cb_row4_col0" class="data row4 col0" >0.209184</td>
#       <td id="T_625cb_row4_col1" class="data row4 col1" >0.194446</td>
#       <td id="T_625cb_row4_col2" class="data row4 col2" >0.034131</td>
#       <td id="T_625cb_row4_col3" class="data row4 col3" >0.585495</td>
#       <td id="T_625cb_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_625cb_row4_col5" class="data row4 col5" >0.369361</td>
#       <td id="T_625cb_row4_col6" class="data row4 col6" >-0.152718</td>
#     </tr>
#     <tr>
#       <th id="T_625cb_level0_row5" class="row_heading level0 row5" >Temp Werkzeug / degC</th>
#       <td id="T_625cb_row5_col0" class="data row5 col0" >0.898679</td>
#       <td id="T_625cb_row5_col1" class="data row5 col1" >0.981825</td>
#       <td id="T_625cb_row5_col2" class="data row5 col2" >0.014837</td>
#       <td id="T_625cb_row5_col3" class="data row5 col3" >0.077946</td>
#       <td id="T_625cb_row5_col4" class="data row5 col4" >0.369361</td>
#       <td id="T_625cb_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_625cb_row5_col6" class="data row5 col6" >-0.496322</td>
#     </tr>
#     <tr>
#       <th id="T_625cb_level0_row6" class="row_heading level0 row6" >Bearbeitungszeit / s</th>
#       <td id="T_625cb_row6_col0" class="data row6 col0" >-0.573392</td>
#       <td id="T_625cb_row6_col1" class="data row6 col1" >-0.492981</td>
#       <td id="T_625cb_row6_col2" class="data row6 col2" >-0.007918</td>
#       <td id="T_625cb_row6_col3" class="data row6 col3" >0.024696</td>
#       <td id="T_625cb_row6_col4" class="data row6 col4" >-0.152718</td>
#       <td id="T_625cb_row6_col5" class="data row6 col5" >-0.496322</td>
#       <td id="T_625cb_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Deckt sich die berechnete Korrelation mit Ihren Erkenntnissen aus den Streudiagrammen? Fallen Ihnen noch weitere interessante Zusammenhänge auf? Manchmal ergeben sich interessante Zusammenhänge erst, wenn man verschiedene Merkmale miteinander kombiniert. So können wir zum Beispiel die Spannung aus der Drehzahl, dem Drehmoment und der Stromstärke [berechnen](https://en.wikipedia.org/wiki/Electric_motor). Lassen Sie uns hierzu eine neue Spalte in unserer Tabelle anlegen:

# %%
exploration_data["Spannung / V"] = (2 * 3.14 / 60 * exploration_data["Drehzahl / 1/min"] *
exploration_data["Drehmoment / Nm"] / exploration_data["Strom / A"])

# %% [markdown]
# Nun können wir die Korrelationskoeffizienten nach Pearson für unser neues Merkmal noch einmal darstellen:

# %%
corr = exploration_data.corr(numeric_only=True)
corr.style.background_gradient(vmin=-1, vmax=1, cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_2e031_row0_col0, #T_2e031_row1_col1, #T_2e031_row2_col2, #T_2e031_row3_col3, #T_2e031_row4_col4, #T_2e031_row5_col5, #T_2e031_row6_col6, #T_2e031_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_2e031_row0_col1, #T_2e031_row1_col0 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_2e031_row0_col2, #T_2e031_row1_col2, #T_2e031_row2_col0, #T_2e031_row2_col1 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_2e031_row0_col3, #T_2e031_row3_col0 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_2e031_row0_col4, #T_2e031_row4_col0 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_2e031_row0_col5, #T_2e031_row5_col0 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_2e031_row0_col6, #T_2e031_row6_col0 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_2e031_row0_col7, #T_2e031_row7_col0 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_2e031_row1_col3, #T_2e031_row3_col1 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_2e031_row1_col4, #T_2e031_row4_col1 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_2e031_row1_col5, #T_2e031_row5_col1 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_2e031_row1_col6, #T_2e031_row5_col6, #T_2e031_row6_col1, #T_2e031_row6_col5 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_2e031_row1_col7, #T_2e031_row7_col1 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_2e031_row2_col3, #T_2e031_row2_col4, #T_2e031_row3_col2, #T_2e031_row4_col2 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_2e031_row2_col5, #T_2e031_row2_col7, #T_2e031_row5_col2, #T_2e031_row7_col2 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_2e031_row2_col6, #T_2e031_row6_col2 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_2e031_row3_col4, #T_2e031_row4_col3 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_2e031_row3_col5, #T_2e031_row5_col3 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_2e031_row3_col6, #T_2e031_row6_col3 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_2e031_row3_col7, #T_2e031_row7_col3 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_2e031_row4_col5, #T_2e031_row5_col4 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_2e031_row4_col6, #T_2e031_row4_col7, #T_2e031_row6_col4, #T_2e031_row7_col4 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_2e031_row5_col7, #T_2e031_row7_col5 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_2e031_row6_col7, #T_2e031_row7_col6 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# </style>
# <table id="T_2e031">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e031_level0_col0" class="col_heading level0 col0" >Strom / A</th>
#       <th id="T_2e031_level0_col1" class="col_heading level0 col1" >Drehmoment / Nm</th>
#       <th id="T_2e031_level0_col2" class="col_heading level0 col2" >Drehzahl / 1/min</th>
#       <th id="T_2e031_level0_col3" class="col_heading level0 col3" >Temp Umgebung / degC</th>
#       <th id="T_2e031_level0_col4" class="col_heading level0 col4" >Temp Umrichter / degC</th>
#       <th id="T_2e031_level0_col5" class="col_heading level0 col5" >Temp Werkzeug / degC</th>
#       <th id="T_2e031_level0_col6" class="col_heading level0 col6" >Bearbeitungszeit / s</th>
#       <th id="T_2e031_level0_col7" class="col_heading level0 col7" >Spannung / V</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e031_level0_row0" class="row_heading level0 row0" >Strom / A</th>
#       <td id="T_2e031_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_2e031_row0_col1" class="data row0 col1" >0.908122</td>
#       <td id="T_2e031_row0_col2" class="data row0 col2" >-0.000045</td>
#       <td id="T_2e031_row0_col3" class="data row0 col3" >-0.049613</td>
#       <td id="T_2e031_row0_col4" class="data row0 col4" >0.209184</td>
#       <td id="T_2e031_row0_col5" class="data row0 col5" >0.898679</td>
#       <td id="T_2e031_row0_col6" class="data row0 col6" >-0.573392</td>
#       <td id="T_2e031_row0_col7" class="data row0 col7" >-0.785425</td>
#     </tr>
#     <tr>
#       <th id="T_2e031_level0_row1" class="row_heading level0 row1" >Drehmoment / Nm</th>
#       <td id="T_2e031_row1_col0" class="data row1 col0" >0.908122</td>
#       <td id="T_2e031_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_2e031_row1_col2" class="data row1 col2" >-0.006215</td>
#       <td id="T_2e031_row1_col3" class="data row1 col3" >-0.034505</td>
#       <td id="T_2e031_row1_col4" class="data row1 col4" >0.194446</td>
#       <td id="T_2e031_row1_col5" class="data row1 col5" >0.981825</td>
#       <td id="T_2e031_row1_col6" class="data row1 col6" >-0.492981</td>
#       <td id="T_2e031_row1_col7" class="data row1 col7" >-0.456005</td>
#     </tr>
#     <tr>
#       <th id="T_2e031_level0_row2" class="row_heading level0 row2" >Drehzahl / 1/min</th>
#       <td id="T_2e031_row2_col0" class="data row2 col0" >-0.000045</td>
#       <td id="T_2e031_row2_col1" class="data row2 col1" >-0.006215</td>
#       <td id="T_2e031_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_2e031_row2_col3" class="data row2 col3" >0.035159</td>
#       <td id="T_2e031_row2_col4" class="data row2 col4" >0.034131</td>
#       <td id="T_2e031_row2_col5" class="data row2 col5" >0.014837</td>
#       <td id="T_2e031_row2_col6" class="data row2 col6" >-0.007918</td>
#       <td id="T_2e031_row2_col7" class="data row2 col7" >0.014566</td>
#     </tr>
#     <tr>
#       <th id="T_2e031_level0_row3" class="row_heading level0 row3" >Temp Umgebung / degC</th>
#       <td id="T_2e031_row3_col0" class="data row3 col0" >-0.049613</td>
#       <td id="T_2e031_row3_col1" class="data row3 col1" >-0.034505</td>
#       <td id="T_2e031_row3_col2" class="data row3 col2" >0.035159</td>
#       <td id="T_2e031_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_2e031_row3_col4" class="data row3 col4" >0.585495</td>
#       <td id="T_2e031_row3_col5" class="data row3 col5" >0.077946</td>
#       <td id="T_2e031_row3_col6" class="data row3 col6" >0.024696</td>
#       <td id="T_2e031_row3_col7" class="data row3 col7" >0.061726</td>
#     </tr>
#     <tr>
#       <th id="T_2e031_level0_row4" class="row_heading level0 row4" >Temp Umrichter / degC</th>
#       <td id="T_2e031_row4_col0" class="data row4 col0" >0.209184</td>
#       <td id="T_2e031_row4_col1" class="data row4 col1" >0.194446</td>
#       <td id="T_2e031_row4_col2" class="data row4 col2" >0.034131</td>
#       <td id="T_2e031_row4_col3" class="data row4 col3" >0.585495</td>
#       <td id="T_2e031_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_2e031_row4_col5" class="data row4 col5" >0.369361</td>
#       <td id="T_2e031_row4_col6" class="data row4 col6" >-0.152718</td>
#       <td id="T_2e031_row4_col7" class="data row4 col7" >-0.153258</td>
#     </tr>
#     <tr>
#       <th id="T_2e031_level0_row5" class="row_heading level0 row5" >Temp Werkzeug / degC</th>
#       <td id="T_2e031_row5_col0" class="data row5 col0" >0.898679</td>
#       <td id="T_2e031_row5_col1" class="data row5 col1" >0.981825</td>
#       <td id="T_2e031_row5_col2" class="data row5 col2" >0.014837</td>
#       <td id="T_2e031_row5_col3" class="data row5 col3" >0.077946</td>
#       <td id="T_2e031_row5_col4" class="data row5 col4" >0.369361</td>
#       <td id="T_2e031_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_2e031_row5_col6" class="data row5 col6" >-0.496322</td>
#       <td id="T_2e031_row5_col7" class="data row5 col7" >-0.461445</td>
#     </tr>
#     <tr>
#       <th id="T_2e031_level0_row6" class="row_heading level0 row6" >Bearbeitungszeit / s</th>
#       <td id="T_2e031_row6_col0" class="data row6 col0" >-0.573392</td>
#       <td id="T_2e031_row6_col1" class="data row6 col1" >-0.492981</td>
#       <td id="T_2e031_row6_col2" class="data row6 col2" >-0.007918</td>
#       <td id="T_2e031_row6_col3" class="data row6 col3" >0.024696</td>
#       <td id="T_2e031_row6_col4" class="data row6 col4" >-0.152718</td>
#       <td id="T_2e031_row6_col5" class="data row6 col5" >-0.496322</td>
#       <td id="T_2e031_row6_co

# %% [markdown]
# Ergeben sich durch unser neues Merkmal neue interessante Zusammenhänge? Versuchen Sie nun selbst, eine Hypothese darüber aufzustellen, welche Merkmalskombination interessante Zusammenhänge zeigen könnte. Ohne Wissen über mechatronische Systeme erwarten wir natürlich nicht, dass Ihre Hypothese plausibel ist. Für unsere Zwecke würde daher auch die Hypothese genügen, dass sich durch die Multiplikation oder Division zweier beliebiger Merkmale möglicherweise ein neues interessantes Merkmal ergeben könnte.
#
# <span style="color:#FF5F00"><b>AUFGABE 7:</b></span><br>
# Legen Sie in der Tabelle dann eine neue Spalte für Ihr Merkmal an und lassen Sie sich die Korrelationskoeffizienten nach Pearson in einer Heatmap ausgeben. Nicht-benötige Spalten können Sie bei Bedarf mit ```del exploration_data["..."]``` löschen, indem sie ```...``` durch den Spaltennamen ersetzen. Achtung - solche Befehle können Sie offensichtlich nicht wiederholt ausfüllen.

# %%
exploration_data["M*n Leistung / W"] = 2 * 3.14 * exploration_data["Drehzahl / 1/min"] * exploration_data["Drehmoment / Nm"]
exploration_data["U*I Leistung / W"] = exploration_data["Strom / A"] * exploration_data["Spannung / V"]


corr = exploration_data.corr(numeric_only=True, method="spearman")
corr.style.background_gradient(vmin=-1, vmax=1, cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_7a8a9_row0_col0, #T_7a8a9_row1_col1, #T_7a8a9_row1_col8, #T_7a8a9_row1_col9, #T_7a8a9_row2_col2, #T_7a8a9_row3_col3, #T_7a8a9_row4_col4, #T_7a8a9_row5_col5, #T_7a8a9_row6_col6, #T_7a8a9_row7_col7, #T_7a8a9_row8_col1, #T_7a8a9_row8_col8, #T_7a8a9_row8_col9, #T_7a8a9_row9_col1, #T_7a8a9_row9_col8, #T_7a8a9_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_7a8a9_row0_col1, #T_7a8a9_row0_col8, #T_7a8a9_row0_col9, #T_7a8a9_row1_col0, #T_7a8a9_row8_col0, #T_7a8a9_row9_col0 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_7a8a9_row0_col2, #T_7a8a9_row1_col2, #T_7a8a9_row2_col0, #T_7a8a9_row2_col1 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_7a8a9_row0_col3, #T_7a8a9_row3_col0 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_7a8a9_row0_col4, #T_7a8a9_row4_col0, #T_7a8a9_row4_col8, #T_7a8a9_row4_col9, #T_7a8a9_row8_col4, #T_7a8a9_row9_col4 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_7a8a9_row0_col5, #T_7a8a9_row5_col0 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_7a8a9_row0_col6, #T_7a8a9_row6_col0 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_7a8a9_row0_col7, #T_7a8a9_row7_col0 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_7a8a9_row1_col3, #T_7a8a9_row3_col1, #T_7a8a9_row3_col8, #T_7a8a9_row3_col9, #T_7a8a9_row8_col3, #T_7a8a9_row9_col3 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_7a8a9_row1_col4, #T_7a8a9_row4_col1 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_7a8a9_row1_col5, #T_7a8a9_row5_col1, #T_7a8a9_row5_col8, #T_7a8a9_row5_col9, #T_7a8a9_row8_col5, #T_7a8a9_row9_col5 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_7a8a9_row1_col6, #T_7a8a9_row6_col1, #T_7a8a9_row6_col8, #T_7a8a9_row6_col9, #T_7a8a9_row8_col6, #T_7a8a9_row9_col6 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_7a8a9_row1_col7, #T_7a8a9_row7_col1, #T_7a8a9_row7_col8, #T_7a8a9_row7_col9, #T_7a8a9_row8_col7, #T_7a8a9_row9_col7 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_7a8a9_row2_col3, #T_7a8a9_row2_col4, #T_7a8a9_row3_col2, #T_7a8a9_row3_col7, #T_7a8a9_row4_col2, #T_7a8a9_row7_col3 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_7a8a9_row2_col5, #T_7a8a9_row3_col6, #T_7a8a9_row5_col2, #T_7a8a9_row6_col3 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_7a8a9_row2_col6, #T_7a8a9_row6_col2 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_7a8a9_row2_col7, #T_7a8a9_row7_col2 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_7a8a9_row2_col8, #T_7a8a9_row2_col9, #T_7a8a9_row8_col2, #T_7a8a9_row9_col2 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_7a8a9_row3_col4, #T_7a8a9_row4_col3 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_7a8a9_row3_col5, #T_7a8a9_row5_col3 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_7a8a9_row4_col5, #T_7a8a9_row5_col4 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_7a8a9_row4_col6, #T_7a8a9_row6_col4 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_7a8a9_row4_col7, #T_7a8a9_row7_col4 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_7a8a9_row5_col6, #T_7a8a9_row6_col5 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_7a8a9_row5_col7, #T_7a8a9_row7_col5 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_7a8a9_row6_col7, #T_7a8a9_row7_col6 {
#   background-color: #f6a283;
#   color: #000000;
# }
# </style>
# <table id="T_7a8a9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7a8a9_level0_col0" class="col_heading level0 col0" >Strom / A</th>
#       <th id="T_7a8a9_level0_col1" class="col_heading level0 col1" >Drehmoment / Nm</th>
#       <th id="T_7a8a9_level0_col2" class="col_heading level0 col2" >Drehzahl / 1/min</th>
#       <th id="T_7a8a9_level0_col3" class="col_heading level0 col3" >Temp Umgebung / degC</th>
#       <th id="T_7a8a9_level0_col4" class="col_heading level0 col4" >Temp Umrichter / degC</th>
#       <th id="T_7a8a9_level0_col5" class="col_heading level0 col5" >Temp Werkzeug / degC</th>
#       <th id="T_7a8a9_level0_col6" class="col_heading level0 col6" >Bearbeitungszeit / s</th>
#       <th id="T_7a8a9_level0_col7" class="col_heading level0 col7" >Spannung / V</th>
#       <th id="T_7a8a9_level0_col8" class="col_heading level0 col8" >M*n Leistung / W</th>
#       <th id="T_7a8a9_level0_col9" class="col_heading level0 col9" >U*I Leistung / W</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a8a9_level0_row0" class="row_heading level0 row0" >Strom / A</th>
#       <td id="T_7a8a9_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_7a8a9_row0_col1" class="data row0 col1" >0.884248</td>
#       <td id="T_7a8a9_row0_col2" class="data row0 col2" >0.013911</td>
#       <td id="T_7a8a9_row0_col3" class="data row0 col3" >-0.074814</td>
#       <td id="T_7a8a9_row0_col4" class="data row0 col4" >0.191843</td>
#       <td id="T_7a8a9_row0_col5" class="data row0 col5" >0.869354</td>
#       <td id="T_7a8a9_row0_col6" class="data row0 col6" >-0.625860</td>
#       <td id="T_7a8a9_row0_col7" class="data row0 col7" >-0.725837</td>
#       <td id="T_7a8a9_row0_col8" class="data row0 col8" >0.884352</td>
#       <td id="T_7a8a9_row0_col9" class="data row0 col9" >0.884362</td>
#     </tr>
#     <tr>
#       <th id="T_7a8a9_level0_row1" class="row_heading level0 row1" >Drehmoment / Nm</th>
#       <td id="T_7a8a9_row1_col0" class="data row1 col0" >0.884248</td>
#       <td id="T_7a8a9_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_7a8a9_row1_col2" class="data row1 col2" >0.011221</td>
#       <td id="T_7a8a9_row1_col3" class="data row1 col3" >-0.052199</td>
#       <td id="T_7a8a9_row1_col4" class="data row1 col4" >0.186695</td>
#       <td id="T_7a8a9_row1_col5" class="data row1 col5" >0.974324</td>
#       <td id="T_7a8a9_row1_col6" class="data row1 col6" >-0.617848</td>
#       <td id="T_7a8a9_row1_col7" class="data row1 col7" >-0.411200</td>
#       <td id="T_7a8a9_row1_col8" class="data row1 col8" >0.999727</td>
#       <td id="T_7a8a9_row1_col9" class="data row1 col9" >0.999726</td>
#     </tr>
#     <tr>
#       <th id="T_7a8a9_level0_row2" class="row_heading level0 row2" >Drehzahl / 1/min</th>
#       <td id="T_7a8a9_row2_col0" class="data row2 col0" >0.013911</td>
#       <td id="T_7a8a9_row2_col1" class="data row2 col1" >0.011221</td>
#       <td id="T_7a8a9_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_7a8a9_row2_col3" class="data row2 col3" >0.054004</td>
#       <td id="T_7a8a9_row2_col4" class="data row2 col4" >0.051053</td>
#       <td id="T_7a8a9_row2_col5" class="data row2 col5" >0.033030</td>
#       <td id="T_7a8a9_row2_col6" class="data row2 col6" >-0.007508</td>
#       <td id="T_7a8a9_row2_col7" class="data row2 col7" >0.055122</td>
#       <td id="T_7a8a9_row2_col8" class="data row2 col8" >0.030549</td>
#       <td id="T_7a8a9_row2_col9" class="data row2 col9" >0.030598</td>
#     </tr>
#     <tr>
#       <th id="T_7a8a9_level0_row3" class="row_heading level0 row3" >Temp Umgebung / degC</th>
#       <td id="T_7a8a9_row3_col0" class="data row3 col0" >-0.074814</td>
#       <td id="T_7a8a9_row3_col1" class="data row3 col1" >-0.052199</td>
#       <td id="T_7a8a9_row3_col2" class="data row3 col2" >0.054004</td>
#       <td id="T_7a8a9_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_7a8a9_row3_col4" class="data row3 col4" >0.567779</td>
#       <td id="T_7a8a9_row3_col5" class="data row3 col5" >0.070860</td>
#       <td id="T_7a8a9_row3_col6" class="data row3 col6" >0.032639</td>
#       <td id="T_7a8a9_row3_col7" class="data row3 col7" >0.047984</td>
#       <td id="T_7a8a9_row3_col8" class="data row3 col8" >-0.050743</td>
#       <td id="T_7a8a9_row3_col9" class="data row3 col9" >-0.050701</td>
#     </tr>
#     <tr>
#       <th id="T_7a8a9_level0_row4" class="row_heading level0 row4" >Temp Umrichter / degC</th>
#       <td id="T_7a8a9_row4_col0" class="data row4 col0" >0.191843</td>
#       <td id="T_7a8a9_row4_col1" class="data row4 col1" >0.186695</td>
#       <td id="T_7a8a9_row4_col2" class="data row4 col2" >0.051053</td>
#       <td id="T_7a8a9_row4_col3" class="data ro

# %%
corr = exploration_data.corr(numeric_only=True, method="kendall")
corr.style.background_gradient(vmin=-1, vmax=1, cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_fc3a7_row0_col0, #T_fc3a7_row1_col1, #T_fc3a7_row2_col2, #T_fc3a7_row3_col3, #T_fc3a7_row4_col4, #T_fc3a7_row5_col5, #T_fc3a7_row6_col6, #T_fc3a7_row7_col7, #T_fc3a7_row8_col8, #T_fc3a7_row8_col9, #T_fc3a7_row9_col8, #T_fc3a7_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_fc3a7_row0_col1, #T_fc3a7_row1_col0 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_fc3a7_row0_col2, #T_fc3a7_row1_col2, #T_fc3a7_row2_col0, #T_fc3a7_row2_col1 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_fc3a7_row0_col3, #T_fc3a7_row3_col0 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_fc3a7_row0_col4, #T_fc3a7_row1_col4, #T_fc3a7_row4_col0, #T_fc3a7_row4_col1, #T_fc3a7_row4_col8, #T_fc3a7_row4_col9, #T_fc3a7_row8_col4, #T_fc3a7_row9_col4 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_fc3a7_row0_col5, #T_fc3a7_row5_col0 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_fc3a7_row0_col6, #T_fc3a7_row6_col0 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_fc3a7_row0_col7, #T_fc3a7_row7_col0 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_fc3a7_row0_col8, #T_fc3a7_row0_col9, #T_fc3a7_row8_col0, #T_fc3a7_row9_col0 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_fc3a7_row1_col3, #T_fc3a7_row3_col1, #T_fc3a7_row3_col8, #T_fc3a7_row3_col9, #T_fc3a7_row8_col3, #T_fc3a7_row9_col3 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_fc3a7_row1_col5, #T_fc3a7_row5_col1, #T_fc3a7_row5_col8, #T_fc3a7_row5_col9, #T_fc3a7_row8_col5, #T_fc3a7_row9_col5 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_fc3a7_row1_col6, #T_fc3a7_row6_col1, #T_fc3a7_row6_col8, #T_fc3a7_row6_col9, #T_fc3a7_row8_col6, #T_fc3a7_row9_col6 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_fc3a7_row1_col7, #T_fc3a7_row7_col1, #T_fc3a7_row7_col8, #T_fc3a7_row7_col9, #T_fc3a7_row8_col7, #T_fc3a7_row9_col7 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_fc3a7_row1_col8, #T_fc3a7_row1_col9, #T_fc3a7_row8_col1, #T_fc3a7_row9_col1 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_fc3a7_row2_col3, #T_fc3a7_row2_col4, #T_fc3a7_row3_col2, #T_fc3a7_row3_col7, #T_fc3a7_row4_col2, #T_fc3a7_row7_col3 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_fc3a7_row2_col5, #T_fc3a7_row5_col2 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_fc3a7_row2_col6, #T_fc3a7_row6_col2 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_fc3a7_row2_col7, #T_fc3a7_row7_col2 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_fc3a7_row2_col8, #T_fc3a7_row2_col9, #T_fc3a7_row3_col6, #T_fc3a7_row6_col3, #T_fc3a7_row8_col2, #T_fc3a7_row9_col2 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_fc3a7_row3_col4, #T_fc3a7_row4_col3 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_fc3a7_row3_col5, #T_fc3a7_row5_col3 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_fc3a7_row4_col5, #T_fc3a7_row5_col4 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_fc3a7_row4_col6, #T_fc3a7_row6_col4 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_fc3a7_row4_col7, #T_fc3a7_row7_col4 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_fc3a7_row5_col6, #T_fc3a7_row6_col5 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_fc3a7_row5_col7, #T_fc3a7_row7_col5 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_fc3a7_row6_col7, #T_fc3a7_row7_col6 {
#   background-color: #f7b599;
#   color: #000000;
# }
# </style>
# <table id="T_fc3a7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc3a7_level0_col0" class="col_heading level0 col0" >Strom / A</th>
#       <th id="T_fc3a7_level0_col1" class="col_heading level0 col1" >Drehmoment / Nm</th>
#       <th id="T_fc3a7_level0_col2" class="col_heading level0 col2" >Drehzahl / 1/min</th>
#       <th id="T_fc3a7_level0_col3" class="col_heading level0 col3" >Temp Umgebung / degC</th>
#       <th id="T_fc3a7_level0_col4" class="col_heading level0 col4" >Temp Umrichter / degC</th>
#       <th id="T_fc3a7_level0_col5" class="col_heading level0 col5" >Temp Werkzeug / degC</th>
#       <th id="T_fc3a7_level0_col6" class="col_heading level0 col6" >Bearbeitungszeit / s</th>
#       <th id="T_fc3a7_level0_col7" class="col_heading level0 col7" >Spannung / V</th>
#       <th id="T_fc3a7_level0_col8" class="col_heading level0 col8" >M*n Leistung / W</th>
#       <th id="T_fc3a7_level0_col9" class="col_heading level0 col9" >U*I Leistung / W</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc3a7_level0_row0" class="row_heading level0 row0" >Strom / A</th>
#       <td id="T_fc3a7_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_fc3a7_row0_col1" class="data row0 col1" >0.772600</td>
#       <td id="T_fc3a7_row0_col2" class="data row0 col2" >0.010241</td>
#       <td id="T_fc3a7_row0_col3" class="data row0 col3" >-0.048601</td>
#       <td id="T_fc3a7_row0_col4" class="data row0 col4" >0.130234</td>
#       <td id="T_fc3a7_row0_col5" class="data row0 col5" >0.715799</td>
#       <td id="T_fc3a7_row0_col6" class="data row0 col6" >-0.460986</td>
#       <td id="T_fc3a7_row0_col7" class="data row0 col7" >-0.502981</td>
#       <td id="T_fc3a7_row0_col8" class="data row0 col8" >0.777247</td>
#       <td id="T_fc3a7_row0_col9" class="data row0 col9" >0.777225</td>
#     </tr>
#     <tr>
#       <th id="T_fc3a7_level0_row1" class="row_heading level0 row1" >Drehmoment / Nm</th>
#       <td id="T_fc3a7_row1_col0" class="data row1 col0" >0.772600</td>
#       <td id="T_fc3a7_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_fc3a7_row1_col2" class="data row1 col2" >0.008731</td>
#       <td id="T_fc3a7_row1_col3" class="data row1 col3" >-0.033773</td>
#       <td id="T_fc3a7_row1_col4" class="data row1 col4" >0.128205</td>
#       <td id="T_fc3a7_row1_col5" class="data row1 col5" >0.866456</td>
#       <td id="T_fc3a7_row1_col6" class="data row1 col6" >-0.435991</td>
#       <td id="T_fc3a7_row1_col7" class="data row1 col7" >-0.280806</td>
#       <td id="T_fc3a7_row1_col8" class="data row1 col8" >0.987570</td>
#       <td id="T_fc3a7_row1_col9" class="data row1 col9" >0.987537</td>
#     </tr>
#     <tr>
#       <th id="T_fc3a7_level0_row2" class="row_heading level0 row2" >Drehzahl / 1/min</th>
#       <td id="T_fc3a7_row2_col0" class="data row2 col0" >0.010241</td>
#       <td id="T_fc3a7_row2_col1" class="data row2 col1" >0.008731</td>
#       <td id="T_fc3a7_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_fc3a7_row2_col3" class="data row2 col3" >0.038677</td>
#       <td id="T_fc3a7_row2_col4" class="data row2 col4" >0.035235</td>
#       <td id="T_fc3a7_row2_col5" class="data row2 col5" >0.024229</td>
#       <td id="T_fc3a7_row2_col6" class="data row2 col6" >-0.005491</td>
#       <td id="T_fc3a7_row2_col7" class="data row2 col7" >0.039798</td>
#       <td id="T_fc3a7_row2_col8" class="data row2 col8" >0.022579</td>
#       <td id="T_fc3a7_row2_col9" class="data row2 col9" >0.022625</td>
#     </tr>
#     <tr>
#       <th id="T_fc3a7_level0_row3" class="row_heading level0 row3" >Temp Umgebung / degC</th>
#       <td id="T_fc3a7_row3_col0" class="data row3 col0" >-0.048601</td>
#       <td id="T_fc3a7_row3_col1" class="data row3 col1" >-0.033773</td>
#       <td id="T_fc3a7_row3_col2" class="data row3 col2" >0.038677</td>
#       <td id="T_fc3a7_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_fc3a7_row3_col4" class="data row3 col4" >0.407311</td>
#       <td id="T_fc3a7_row3_col5" class="data row3 col5" >0.048875</td>
#       <td id="T_fc3a7_row3_col6" class="data row3 col6" >0.023352</td>
#       <td id="T_fc3a7_row3_col7" class="data row3 col7" >0.033278</td>
#       <td id="T_fc3a7_row3_col8" class="data row3 col8" >-0.032767</td>
#       <td id="T_fc3a7_row3_col9" class="data row3 col9" >-0.032727</td>
#     </tr>
#     <tr>
#       <th id="T_fc3a7_level0_row4" class="row_heading level0 row4" >Temp Umrichter / degC</th>
#       <td id="T_fc3a7_row4_col0" class="data row4 col0" >0.130234</td>
#       <td id="T_fc3a7_row4_col1" class="data row4 col1" >0.128205</td>
#       <td id="T_fc3a7_row4_col2" class="data row4 col2" >0.035235</t

# %%
corr = exploration_data.corr(numeric_only=True, method="pearson")
corr.style.background_gradient(vmin=-1, vmax=1, cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_31d32_row0_col0, #T_31d32_row1_col1, #T_31d32_row1_col8, #T_31d32_row1_col9, #T_31d32_row2_col2, #T_31d32_row3_col3, #T_31d32_row4_col4, #T_31d32_row5_col5, #T_31d32_row6_col6, #T_31d32_row7_col7, #T_31d32_row8_col1, #T_31d32_row8_col8, #T_31d32_row8_col9, #T_31d32_row9_col1, #T_31d32_row9_col8, #T_31d32_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_31d32_row0_col1, #T_31d32_row0_col8, #T_31d32_row0_col9, #T_31d32_row1_col0, #T_31d32_row8_col0, #T_31d32_row9_col0 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_31d32_row0_col2, #T_31d32_row1_col2, #T_31d32_row2_col0, #T_31d32_row2_col1 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_31d32_row0_col3, #T_31d32_row3_col0 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_31d32_row0_col4, #T_31d32_row4_col0 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_31d32_row0_col5, #T_31d32_row5_col0 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_31d32_row0_col6, #T_31d32_row6_col0 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_31d32_row0_col7, #T_31d32_row7_col0 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_31d32_row1_col3, #T_31d32_row3_col1, #T_31d32_row3_col8, #T_31d32_row3_col9, #T_31d32_row8_col3, #T_31d32_row9_col3 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_31d32_row1_col4, #T_31d32_row4_col1, #T_31d32_row4_col8, #T_31d32_row4_col9, #T_31d32_row8_col4, #T_31d32_row9_col4 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_31d32_row1_col5, #T_31d32_row5_col1, #T_31d32_row5_col8, #T_31d32_row5_col9, #T_31d32_row8_col5, #T_31d32_row9_col5 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_31d32_row1_col6, #T_31d32_row5_col6, #T_31d32_row6_col1, #T_31d32_row6_col5, #T_31d32_row6_col8, #T_31d32_row6_col9, #T_31d32_row8_col6, #T_31d32_row9_col6 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_31d32_row1_col7, #T_31d32_row7_col1, #T_31d32_row7_col8, #T_31d32_row7_col9, #T_31d32_row8_col7, #T_31d32_row9_col7 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_31d32_row2_col3, #T_31d32_row2_col4, #T_31d32_row3_col2, #T_31d32_row4_col2 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_31d32_row2_col5, #T_31d32_row2_col7, #T_31d32_row2_col8, #T_31d32_row2_col9, #T_31d32_row5_col2, #T_31d32_row7_col2, #T_31d32_row8_col2, #T_31d32_row9_col2 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_31d32_row2_col6, #T_31d32_row6_col2 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_31d32_row3_col4, #T_31d32_row4_col3 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_31d32_row3_col5, #T_31d32_row5_col3 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_31d32_row3_col6, #T_31d32_row6_col3 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_31d32_row3_col7, #T_31d32_row7_col3 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_31d32_row4_col5, #T_31d32_row5_col4 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_31d32_row4_col6, #T_31d32_row4_col7, #T_31d32_row6_col4, #T_31d32_row7_col4 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_31d32_row5_col7, #T_31d32_row7_col5 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_31d32_row6_col7, #T_31d32_row7_col6 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# </style>
# <table id="T_31d32">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_31d32_level0_col0" class="col_heading level0 col0" >Strom / A</th>
#       <th id="T_31d32_level0_col1" class="col_heading level0 col1" >Drehmoment / Nm</th>
#       <th id="T_31d32_level0_col2" class="col_heading level0 col2" >Drehzahl / 1/min</th>
#       <th id="T_31d32_level0_col3" class="col_heading level0 col3" >Temp Umgebung / degC</th>
#       <th id="T_31d32_level0_col4" class="col_heading level0 col4" >Temp Umrichter / degC</th>
#       <th id="T_31d32_level0_col5" class="col_heading level0 col5" >Temp Werkzeug / degC</th>
#       <th id="T_31d32_level0_col6" class="col_heading level0 col6" >Bearbeitungszeit / s</th>
#       <th id="T_31d32_level0_col7" class="col_heading level0 col7" >Spannung / V</th>
#       <th id="T_31d32_level0_col8" class="col_heading level0 col8" >M*n Leistung / W</th>
#       <th id="T_31d32_level0_col9" class="col_heading level0 col9" >U*I Leistung / W</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_31d32_level0_row0" class="row_heading level0 row0" >Strom / A</th>
#       <td id="T_31d32_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_31d32_row0_col1" class="data row0 col1" >0.908122</td>
#       <td id="T_31d32_row0_col2" class="data row0 col2" >-0.000045</td>
#       <td id="T_31d32_row0_col3" class="data row0 col3" >-0.049613</td>
#       <td id="T_31d32_row0_col4" class="data row0 col4" >0.209184</td>
#       <td id="T_31d32_row0_col5" class="data row0 col5" >0.898679</td>
#       <td id="T_31d32_row0_col6" class="data row0 col6" >-0.573392</td>
#       <td id="T_31d32_row0_col7" class="data row0 col7" >-0.785425</td>
#       <td id="T_31d32_row0_col8" class="data row0 col8" >0.908088</td>
#       <td id="T_31d32_row0_col9" class="data row0 col9" >0.908088</td>
#     </tr>
#     <tr>
#       <th id="T_31d32_level0_row1" class="row_heading level0 row1" >Drehmoment / Nm</th>
#       <td id="T_31d32_row1_col0" class="data row1 col0" >0.908122</td>
#       <td id="T_31d32_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_31d32_row1_col2" class="data row1 col2" >-0.006215</td>
#       <td id="T_31d32_row1_col3" class="data row1 col3" >-0.034505</td>
#       <td id="T_31d32_row1_col4" class="data row1 col4" >0.194446</td>
#       <td id="T_31d32_row1_col5" class="data row1 col5" >0.981825</td>
#       <td id="T_31d32_row1_col6" class="data row1 col6" >-0.492981</td>
#       <td id="T_31d32_row1_col7" class="data row1 col7" >-0.456005</td>
#       <td id="T_31d32_row1_col8" class="data row1 col8" >0.999850</td>
#       <td id="T_31d32_row1_col9" class="data row1 col9" >0.999850</td>
#     </tr>
#     <tr>
#       <th id="T_31d32_level0_row2" class="row_heading level0 row2" >Drehzahl / 1/min</th>
#       <td id="T_31d32_row2_col0" class="data row2 col0" >-0.000045</td>
#       <td id="T_31d32_row2_col1" class="data row2 col1" >-0.006215</td>
#       <td id="T_31d32_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_31d32_row2_col3" class="data row2 col3" >0.035159</td>
#       <td id="T_31d32_row2_col4" class="data row2 col4" >0.034131</td>
#       <td id="T_31d32_row2_col5" class="data row2 col5" >0.014837</td>
#       <td id="T_31d32_row2_col6" class="data row2 col6" >-0.007918</td>
#       <td id="T_31d32_row2_col7" class="data row2 col7" >0.014566</td>
#       <td id="T_31d32_row2_col8" class="data row2 col8" >0.011034</td>
#       <td id="T_31d32_row2_col9" class="data row2 col9" >0.011041</td>
#     </tr>
#     <tr>
#       <th id="T_31d32_level0_row3" class="row_heading level0 row3" >Temp Umgebung / degC</th>
#       <td id="T_31d32_row3_col0" class="data row3 col0" >-0.049613</td>
#       <td id="T_31d32_row3_col1" class="data row3 col1" >-0.034505</td>
#       <td id="T_31d32_row3_col2" class="data row3 col2" >0.035159</td>
#       <td id="T_31d32_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_31d32_row3_col4" class="data row3 col4" >0.585495</td>
#       <td id="T_31d32_row3_col5" class="data row3 col5" >0.077946</td>
#       <td id="T_31d32_row3_col6" class="data row3 col6" >0.024696</td>
#       <td id="T_31d32_row3_col7" class="data row3 col7" >0.061726</td>
#       <td id="T_31d32_row3_col8" class="data row3 col8" >-0.033895</td>
#       <td id="T_31d32_row3_col9" class="data row3 col9" >-0.033888</td>
#     </tr>
#     <tr>
#       <th id="T_31d32_level0_row4" class="row_heading level0 row4" >Temp Umrichter / degC</th>
#       <td id="T_31d32_row4_col0" class="data row4 col0" >0.209184</td>
#       <td id="T_31d32_row4_col1" class="data row4 col1" >0.194446</td>
#       <td id="T_31d32_row4_col2" class="data row4 col2" >0.034131</td>
#       <td id="T_31d32_row4_col3" class="data row4 col3" >0.585495</td>
#       <td id="T_31d32_row4_col4" class="data row4 col4" >1.000000</td>

# %% [markdown]
# <span style="color:green"><b>Antwort zur AUFGABE 7:</b></span><br>

# %% [markdown]
# Die auf zwei Wege berechnete Leistung zeigt einen klaren Zusammenhang zwischen Strom, Drehzahl und (überraschenderweise) Werkzeugtemperatur! Da die Spannung, die zum berechnen der 2. "U\*I Leistung"-Spalte genutzt wurde, zuvor mithilfe der Gleichung der ersten "M\*n Leistung"-Spalte bestimmt wurde, sind die beiden Spalten natürlich stark korreliert.
#
# ---

# %% [markdown]
# **Prima!**
# Sie haben mit dieser Übung einiges erreicht. Sie können nun sowohl Säulen- oder Balkendiagramme, Histogramme, Streudiagramme als auch Heatmaps in Plotly visualisieren, um einen Datensatz zu erkunden - alles in jeweils nur einer einzigen Zeile Code. Sie haben zudem die wichtigsten Funktionsargumente kennengelernt und haben einige davon auch selbst angepasst. Dass Sie auch eigene Hypothesen aufstellen und testen können, eröffnet Ihnen die Möglichkeit, Ihre eigenen Annahmen auch ohne eine gezielte Datenanalyse auf die Probe zu stellen.
